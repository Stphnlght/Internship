# %%
# importing relevant libraries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains

# %% [markdown]
# ### 1. Search Amazon.in

# %%
driver = webdriver.Chrome(r"C:/Users/ACER/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.amazon.in/')

# %%
product = input()
search_bar = driver.find_element(By.XPATH, '/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search_bar.send_keys(product)
# Out:
# bags

# %%
search_link = driver.find_element(By.XPATH, '/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_link.click()

# %% [markdown]
# ### 2. Scrape Amazon.in

# %%
product_url = []

for i in range(3):
    product_url_tags = driver.find_elements(By.XPATH,'//*[@class="a-link-normal s-no-outline"]')
    for i in product_url_tags:
        prod_url = i.get_attribute("href")
        product_url.append(prod_url)
    next_ = driver.find_element(By.XPATH, '//*[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_.click()
    time.sleep(5)

# %%
product_name = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        product_name_tags = driver.find_elements(By.XPATH,'//*[@class="a-size-large product-title-word-break"]')
        for i in product_name_tags:
            prod_name = i.text
            product_name.append(prod_name)
    except NoSuchElementException:
        product_name.append('-')

# %%
brand_name = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        bran_tags = driver.find_elements(By.XPATH,'//*[@class="a-size-large product-title-word-break"]')
        for i in bran_tags:
            brand_ = i.text.split(' ')[0:2]
            brand_name.append(brand_)
    except NoSuchElementException:
        brand_name.append('-')

# %%
price = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        price_ = driver.find_element(By.XPATH,'//*[@class="a-price-whole"]')
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')

# %%
expect_delivery = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        delivery = driver.find_element(By.XPATH,'//*[@id="mir-layout-DELIVERY_BLOCK-slot-PRIMARY_DELIVERY_MESSAGE_LARGE"]')
        expect_delivery.append(delivery.text)
    except NoSuchElementException:
        expect_delivery.append('-')

# %%
return_exchange = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        exchange = driver.find_element(By.XPATH,'//*[@id="RETURNS_POLICY"]')
        return_exchange.append(exchange.text)
    except NoSuchElementException:
        return_exchange.append('-')

# %%
availability = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        available = driver.find_element(By.XPATH,'//*[@id="availability"]')
        availability.append(available.text)
    except NoSuchElementException:
        availability.append('-')

# %%
df = pd.DataFrame({'Brand Name': brand_name, 'Product Name':product_name, 'Price': price, 'Availability': availability, 'Delivery': expect_delivery, 'Return/Exchange':return_exchange, 'Product Url':product_url})
df.head(10)
# Out:
#                    Brand Name  \
# 0          [WILDOUS, Polaris]
# 1          [WILDOUS, Hunter,]
# 2       [American, Tourister]
# 3    [Northzone, Lightweight]
# 4             [Skybags, Brat]
# 5            [INOVERA, Nylon]
# 6            [MINISO, Simple]
# 7  [PETRICE, Multifunctional]
# 8           [Seagull, flight]
# 9           [Hanging, Travel]
#
#                                         Product Name  Price Availability  \
# 0  WILDOUS Polaris , 23 Liter Casual Water Resist...  1,429    In stock.
# 1  WILDOUS Hunter, 39 Liter Casual Water Resistan...  1,499    In stock.
# 2  American Tourister 32 Ltrs Grey Casual Backpac...      -
# 3  Northzone Lightweight school bags Backpacks fo...    549    In stock.
# 4          Skybags Brat Black 46 Cms Casual Backpack    669    In stock.
# 5  INOVERA Nylon Professional Cosmetic Makeup Kit...    759    In stock.
# 6  MINISO Simple Semicircle Cosmetic Bag Portable...    190    In stock.
# ...

# %%
df.to_csv('amazon_search.csv')

# %% [markdown]
# ### 3. Search Google Images

# %%
driver = webdriver.Chrome(r"C:/Users/ACER/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://images.google.com/')

# %%
search_bar = driver.find_element(By.XPATH, '//*[@class="gLFyf gsfi"]')
search_bar.send_keys('cars')
search_link = driver.find_element(By.XPATH, '//*[@class="z1asCe MZy1Rb"]')
search_link.click()
time.sleep(5)
for i in range(10):
    try:
        img = driver.find_elements(By.XPATH,'//*[@class="rg_i Q4LuWd"]')[i]
        img.screenshot('car' + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %%
driver.get('https://images.google.com/')
search_bar = driver.find_element(By.XPATH, '//*[@class="gLFyf gsfi"]')
search_bar.send_keys('cakes')
search_link = driver.find_element(By.XPATH, '//*[@class="z1asCe MZy1Rb"]')
search_link.click()
time.sleep(5)
for i in range(10):
    try:
        img = driver.find_elements(By.XPATH,'//*[@class="rg_i Q4LuWd"]')[i]
        img.screenshot('cake' + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %%
driver.get('https://images.google.com/')
search_bar = driver.find_element(By.XPATH, '//*[@class="gLFyf gsfi"]')
search_bar.send_keys('machine learning')
search_link = driver.find_element(By.XPATH, '//*[@class="z1asCe MZy1Rb"]')
search_link.click()
time.sleep(5)
for i in range(10):
    try:
        img = driver.find_elements(By.XPATH,'//*[@class="rg_i Q4LuWd"]')[i]
        img.screenshot('ml' + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %%
driver.get('https://images.google.com/')
search_bar = driver.find_element(By.XPATH, '//*[@class="gLFyf gsfi"]')
search_bar.send_keys('fruits')
search_link = driver.find_element(By.XPATH, '//*[@class="z1asCe MZy1Rb"]')
search_link.click()
time.sleep(5)
for i in range(10):
    try:
        img = driver.find_elements(By.XPATH,'//*[@class="rg_i Q4LuWd"]')[i]
        img.screenshot('fruit' + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %%
driver.get('https://images.google.com/')
search_bar = driver.find_element(By.XPATH, '//*[@class="gLFyf gsfi"]')
search_bar.send_keys('guitar')
search_link = driver.find_element(By.XPATH, '//*[@class="z1asCe MZy1Rb"]')
search_link.click()
time.sleep(5)
for i in range(10):
    try:
        img = driver.find_elements(By.XPATH,'//*[@class="rg_i Q4LuWd"]')[i]
        img.screenshot('guitar' + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %% [markdown]
# ### 4. Flipkart Smartphone

# %%
driver = webdriver.Chrome(r"C:/Users/ACER/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
search_bar = driver.find_element(By.XPATH, '//*[@class="_3704LK"]')
search_bar.send_keys('samsung')
search_bar.send_keys(Keys.ENTER)

# %%
product_url = []
product_url_tags = driver.find_elements(By.XPATH,'//*[@class="_1fQZEK"]')
for i in product_url_tags:
    prod_url = i.get_attribute("href")
    product_url.append(prod_url)
time.sleep(5)

# %%
product_name = []
try:
    product_name_tags = driver.find_elements(By.XPATH,'//*[@class="_4rR01T"]')
    for i in product_name_tags:
        product_name.append(i.text.split('(')[0])
except NoSuchElementException:
    product_name.append('-')

# %%
brand_name = []
try:
    bran_tags = driver.find_elements(By.XPATH,'//*[@class="_4rR01T"]')
    for i in bran_tags:
        brand_name.append(i.text.split(' ')[0:2])
except NoSuchElementException:
    brand_name.append('-')

# %%
price = []
try:
    price_tags = driver.find_elements(By.XPATH,'//*[@class="_30jeq3 _1_WHN1"]')
    for i in price_tags:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')

# %%
color = []
try:
    colors = driver.find_elements(By.XPATH,'//*[@class="_4rR01T"]')
    for i in colors:
        try:
            color.append(i.text.split('(')[1].split(',')[0])
        except IndexError:
            color.append('-')
except NoSuchElementException:
    color.append('-')

# %%
ram = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        rams = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[1]')
        ram.append(rams.text.split('|')[0])
    except NoSuchElementException:
        ram.append('-')

# %%
rom = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        roms = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[1]')
        rom.append(roms.text.split('|')[1])
    except NoSuchElementException:
        rom.append('-')

# %%
battery = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        batteries = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[4]')
        battery.append(batteries.text)
    except NoSuchElementException:
        battery.append('-')

# %%
display = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        displays = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[2]')
        display.append(displays.text)
    except NoSuchElementException:
        display.append('-')

# %%
prim_camera = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        prim_cameras = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[3]')
        prim_camera.append(prim_cameras.text.split('|')[0])
    except NoSuchElementException:
        prim_camera.append('-')

# %%
sec_camera = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        sec_cameras = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[3]')
        try:
            sec_camera.append(sec_cameras.text.split('|')[1])
        except IndexError:
            sec_camera.append('-')
    except NoSuchElementException:
        sec_camera.append('-')

# %%
df = pd.DataFrame({'Brand Name': brand_name, 'Product Name':product_name, 'Price': price, 'Ram': ram,
                   'Rom': rom, 'Color':color, 'Product Url':product_url, 'Battery': battery, 'Display': display, 
                   'Primary Camera': prim_camera, 'Secondary Camera': sec_camera})
df.head(10)
# Out:
#           Brand Name            Product Name    Price        Ram  \
# 0  [SAMSUNG, Galaxy]     SAMSUNG Galaxy F13   ₹11,999  4 GB RAM
# 1  [SAMSUNG, Galaxy]     SAMSUNG Galaxy F13   ₹11,999  4 GB RAM
# 2  [SAMSUNG, Galaxy]     SAMSUNG Galaxy F13   ₹11,999  4 GB RAM
# 3  [SAMSUNG, Galaxy]     SAMSUNG Galaxy F22   ₹11,999  4 GB RAM
# 4  [SAMSUNG, Galaxy]     SAMSUNG Galaxy F12   ₹10,499  4 GB RAM
# 5  [SAMSUNG, Galaxy]     SAMSUNG Galaxy F22   ₹13,999  6 GB RAM
# 6  [SAMSUNG, Galaxy]     SAMSUNG Galaxy F22   ₹11,999  4 GB RAM
# 7  [SAMSUNG, Galaxy]  SAMSUNG Galaxy F23 5G   ₹18,499  6 GB RAM
# 8  [SAMSUNG, Galaxy]  SAMSUNG Galaxy F23 5G   ₹18,499  6 GB RAM
# 9  [SAMSUNG, Galaxy]  SAMSUNG Galaxy F23 5G   ₹18,499  6 GB RAM
#
#             Rom           Color  \
# 0    64 GB ROM   Waterfall Blue
# 1    64 GB ROM   Nightsky Green
# 2    64 GB ROM   Sunrise Copper
# 3    64 GB ROM       Denim Blue
# 4    64 GB ROM         Sky Blue
# 5   128 GB ROM      Denim Black
# ...

# %%
df.to_csv('phones.csv')

# %% [markdown]
# ### 5. Geospatial Coordinates

# %%
driver = webdriver.Chrome(r"C:/Users/ACER/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.google.com/maps/')

# %%
location = input()
search_bar = driver.find_element(By.XPATH, '//*[@class="tactile-searchbox-input"]')
search_bar.send_keys(location)
search_bar.send_keys(Keys.ENTER)
# Out:
# mumbai

# %%
url = driver.current_url
url_ = url.split('/')
coords = url_[6]
coords
# Out:
# '@25.0757594,55.5076907,10z'

# %% [markdown]
# ### 6. Funding Deals

# %%
driver = webdriver.Chrome(r"C:/Users/ACER/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.trak.in/')
driver.maximize_window()

# %%
funding = driver.find_element(By.XPATH, '//*[@id="menu-item-51510"]')
funding.click()

# %%
date = []
name = []
industry = []
sub_vertical = []
city = []
ivst_name = []
ivst_type = []
amount = []

dates = driver.find_elements(By.XPATH,'//*[@class="column-2"]')
for i in dates:
    date.append(i.text)
names = driver.find_elements(By.XPATH,'//*[@class="column-3"]')
for i in names:
    name.append(i.text)
subverts = driver.find_elements(By.XPATH,'//*[@class="column-5"]')
for i in subverts:
    sub_vertical.append(i.text)
ivst_names = driver.find_elements(By.XPATH,'//*[@class="column-7"]')
for i in ivst_names:
    ivst_name.append(i.text)
ivst_types = driver.find_elements(By.XPATH,'//*[@class="column-8"]')
for i in ivst_types:
    ivst_type.append(i.text)
cities = driver.find_elements(By.XPATH,'//*[@class="column-6"]')
for i in cities:
    city.append(i.text)
industries = driver.find_elements(By.XPATH,'//*[@class="column-4"]')
for i in industries:
    industry.append(i.text)
amounts = driver.find_elements(By.XPATH,'//*[@class="column-9"]')
for i in amounts:
    amount.append(i.text)

# %%
df1 = pd.DataFrame({'Date':date, 'Name':name, 'Industry':industry, 'Sub-Vertical':sub_vertical, 'Investor Name':ivst_name, 
                   'Investment Type':ivst_type, 'Amount': amount})
df1.head(10)
# Out:
#          Date         Name              Industry  \
# 0  01/04/2021       BYJU’S              Edu-tech
# 1  05/04/2021       Meesho            E-commerce
# 2  14/04/2021       Swiggy  Online Food Delivery
# 3  07/04/2021        Groww               FinTech
# 4  14/04/2021      Beldara            E-commerce
# 5  04/03/2021    DealShare            E-commerce
# 6  31/03/2021     Uniphore            Technology
# 7  30/03/2021        Dunzo            E-commerce
# 8  30/03/2021       BYJU’S              Edu-tech
# 9  23/03/2021  SkilloVilla              Edu-tech
#
#                               Sub-Vertical  \
# 0                          Online tutoring
# 1                Online reselling platform
# 2                     Online Food Delivery
# 3                      Investment platform
# 4                   Global B2B marketplace
# 5                 Online shopping platform
# 6  Conversational Service Automation (CSA)
# 7                 Hyper-local delivery app
# ...

# %% [markdown]
# ### 7. Gaming Laptops

# %%
driver = webdriver.Chrome(r"C:/Users/ACER/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.digit.in/')

# %%
laptops = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[4]/ul/li[3]/a')
laptops.click()
best_laptops = driver.find_element(By.XPATH, '/html/body/div[6]/div/div[2]/div[2]/ul/li[10]/a')
best_laptops.click()

# %%
product_name = []
try:
    product_name_tags = driver.find_elements(By.TAG_NAME,'h3')
    for i in product_name_tags:
        product_name.append(i.text.strip())
except NoSuchElementException:
    product_name.append('-')

# %%
brand_name = []
try:
    bran_tags = driver.find_elements(By.TAG_NAME,'h3')
    for i in bran_tags:
        brand_name.append(i.text.split(' ')[0])
except NoSuchElementException:
    brand_name.append('-')

# %%
product_url = []
product_url_tags = driver.find_elements(By.XPATH,'//div[@class="left_side"]/a')
for i in product_url_tags:
    prod_url = i.get_attribute("href")
    product_url.append(prod_url)

# %%
price = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        price_ = driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div[3]/div[2]/div[4]/div/h2/strong')
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')

# %%
processor = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        processors = driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/div[3]/div[2]/div[3]/div/ul/li[3]/div/p[2]/strong')
        processor.append(processors.text)
    except NoSuchElementException:
        processor.append('-')

# %%
processor
# Out:
# ['12th Gen Intel Core I9-12900HX | NA',
#  '12th Gen Intel Core I9-12900H | 5 GHz',
#  '12th Gen Intel Core I7-12700H | 3.50 GHz',
#  '12th Gen Intel Core I7-12700H | 4.7 GHz',
#  'AMD Ryzen 9-5900HX | NA',
#  'AMD 5th Gen Ryzen 9-5900HX | 3.3GHz',
#  'AMD Ryzen™ 9 5900HX | 3.3 GHz',
#  '12th Gen Intel Core I7-12700H | 2.3 GHz',
#  'AMD Ryzen R7-5800H | 4.40 GHz',
#  'Lenovo Ryzen 7-5800H | 3.2 GHz']

# %%
memory = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        memories = driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div[3]/div[2]/div[3]/div/ul/li[4]/div/p[2]/strong')
        memory.append(memories.text)
    except NoSuchElementException:
        memory.append('-')

# %%
os = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        oss = driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div[3]/div[2]/div[3]/div/ul/li[1]/div/p[2]/strong')
        os.append(oss.text)
    except NoSuchElementException:
        os.append('-')

# %%
display = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        displays = driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div[3]/div[2]/div[3]/div/ul/li[2]/div/p[2]/strong')
        display.append(displays.text)
    except NoSuchElementException:
        display.append('-')

# %%
market = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        markets = driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div[3]/div[2]/div[1]/div[1]/strong')
        market.append(markets.text)
    except NoSuchElementException:
        market.append('-')

# %%
release = []
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        releases = driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div[3]/div[2]/div[1]/div[2]/strong')
        release.append(releases.text)
    except NoSuchElementException:
        release.append('-')

# %%
df = pd.DataFrame({'Brand Name': brand_name, 'Product Name':product_name, 'Price': price, 'Memory': memory,
                   'Market Status': market, 'Release Date':release,'Display': display, 
                   'Operating System': os, 'Processor': processor, 'Product Url':product_url})
df.head(10)
# Out:
#   Brand Name                                   Product Name      Price  \
# 0        MSI                           MSI Titan GT77-12UHS          -
# 1  Alienware                               Alienware X17 R2  ₹ 389,990
# 2       Acer          Acer Predator Triton 500 SE PT516-52s  ₹ 300,000
# 3       Omen                        Omen By HP (16-B1371TX)  ₹ 176,290
# 4       Acer  Acer Predator Helios 300 AN515-45 (NH.QBRSI.0  ₹ 172,999
# 5        MSI                     MSI Delta 15 (A5EFK-083IN)  ₹ 188,990
# 6       Omen                        Omen By HP (16-C0141AX)  ₹ 124,990
# 7     Lenovo              Lenovo Legion 5i Pro (82RF00MGIN)  ₹ 169,990
# 8  Alienware  Alienware M15 R5 Ryzen Edition Icc-C780001win  ₹ 144,990
# 9     Lenovo               Lenovo Slim 7 Gen 6 (82K8002JIN)  ₹ 131,990
#
#                   Memory Market Status  Release Date              Display  \
# 0    2 TB SSD/64 GB DDR5      LAUNCHED  14 Jul, 2022  17.3" (3840 X 2160)
# ...

# %%
df.to_csv('game_laptos.csv')

# %% [markdown]
# ### 8. Billionares

# %%
driver = webdriver.Chrome(r"C:/Users/ACER/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.forbes.com/')

# %%
action = ActionChains(driver)
side_bar = driver.find_element(By.XPATH, '//*[@class="hamburger_svg__fs-icon hamburger_svg__fs-icon--hamburger"]')
action.move_to_element(side_bar).click().perform()
time.sleep(2)
billionares = driver.find_element(By.XPATH, '//*[@class="B1S88Gxl"]')
action.move_to_element(billionares).click().perform()
time.sleep(2)
world = driver.find_element(By.XPATH, '/html/body/div[1]/header/nav/div[1]/div/div/div[2]/ul/li[1]/div[2]/div[3]/ul/li[1]/a')
action.move_to_element(world).click().perform()

# %%
rank = []
name = []
net_worth = []
age = []
source = []
citizenship = []
industry = []

while True:
    ranks = driver.find_elements(By.XPATH,'//*[@class="rank"]')
    for i in ranks:
        rank.append(i.text)
    names = driver.find_elements(By.XPATH,'//*[@class="personName"]')
    for i in names:
        name.append(i.text)
    net_worths = driver.find_elements(By.XPATH,'//*[@class="netWorth"]')
    for i in net_worths:
        net_worth.append(i.text)
    ages = driver.find_elements(By.XPATH,'//*[@class="age"]')
    for i in ages:
        age.append(i.text)
    sources = driver.find_elements(By.XPATH,'//*[@class="source-text"]')
    for i in sources:
        source.append(i.text)
    country = driver.find_elements(By.XPATH,'//*[@class="countryOfCitizenship"]')
    for i in country:
        citizenship.append(i.text)
    industries = driver.find_elements(By.XPATH,'//*[@class="category"]')
    for i in industries:
        industry.append(i.text)
    try:
        next_ = driver.find_element(By.XPATH, '//*[@class="pagination-btn pagination-btn--next "]')
        next_.click()
        time.sleep(5)
    except:
        break

# %%
df = pd.DataFrame({'Rank': rank, 'Name':name, 'Net Worth': net_worth, 'Age': age,
                   'Source': source, 'Citizenship':citizenship,'Industry': industry})
df.head(10)
# Out:
#   Rank                      Name Net Worth Age              Source  \
# 0   1.                 Elon Musk    $219 B  50       Tesla, SpaceX
# 1   2.                Jeff Bezos    $171 B  58              Amazon
# 2   3.  Bernard Arnault & family    $158 B  73                LVMH
# 3   4.                Bill Gates    $129 B  66           Microsoft
# 4   5.            Warren Buffett    $118 B  91  Berkshire Hathaway
# 5   6.                Larry Page    $111 B  49              Google
# 6   7.               Sergey Brin    $107 B  48              Google
# 7   8.             Larry Ellison    $106 B  77            software
# 8   9.             Steve Ballmer   $91.4 B  66           Microsoft
# 9  10.             Mukesh Ambani   $90.7 B  64         diversified
#
#      Citizenship               Industry
# 0  United States             Automotive
# 1  United States             Technology
# 2         France       Fashion & Retail
# 3  United States             Technology
# ...

# %% [markdown]
# ### 9. Youtube

# %%
driver = webdriver.Chrome(r"C:/Users/ACER/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.youtube.com/')
driver.maximize_window()

# %%
search_bar = driver.find_element(By.XPATH, '/html/body/ytd-app/div[1]/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')
search_bar.send_keys('burna boy last last')
search_bar.send_keys(Keys.ENTER)
time.sleep(5)
video = driver.find_element(By.XPATH, '//*[@class="yt-simple-endpoint style-scope ytd-video-renderer"]')
link = video.get_attribute("href")

# %%
driver.get(link)
time.sleep(5)

# %%
pause = 0.5
start_time = time.time()
duration = 45
while True:
    current_time = time.time()
    elapsed_time = current_time - start_time
    html = driver.find_element(By.TAG_NAME,'html')
    html.send_keys(Keys.END)
    time.sleep(pause)
    if elapsed_time >= duration:
        break

# %%
comment = []
comment_upvote = []
comment_time = []
comments = driver.find_elements(By.XPATH,'//*[@id="content-text"]')[0:500]
for i in comments:
    comment.append(i.text)
comment_upvotes = driver.find_elements(By.XPATH,'//*[@id="vote-count-middle"]')[0:500]
for i in comment_upvotes:
    comment_upvote.append(i.text)
comment_times = driver.find_elements(By.XPATH,'//*[@class="published-time-text style-scope ytd-comment-renderer"]')[0:500]
for i in comment_times:
    comment_time.append(i.text)

# %%
df = pd.DataFrame({'Comments': comment, 'Comment Upvote': comment_upvote, 'Comment Time': comment_time})
df.head(10)
# Out:
#                                             Comments Comment Upvote  \
# 0        Burna Boy will win a Grammy from this song             21K
# 1  As a Black American with Igbo roots this song ...            365
# 2  As an African American I'm so happy and excite...            220
# 3  Prayers for the people of Nigeria displaced by...              6
# 4  Ima join everyone else! As a Puerto Rican. The...             16
# 5  M from South Africa 🇿🇦 and I want to thank Nig...             15
# 6         Burna Boy will win a Grammy from this song           4.3K
# 7  I'm from South Africa but listening to this so...            425
# 8  Ayo afrobeat is becoming extremely popular, we...              9
# 9  I'M AN AMERICAN AND I HAVE NO IDEA WHAT HE IS ...            377
#
#            Comment Time
# 0          4 months ago
# 1            9 days ago
# 2            6 days ago
# 3  2 weeks ago (edited)
# 4             1 day ago
# 5            7 days ago
# 6          4 months ago
# ...

# %% [markdown]
# ### 10. Hostel World

# %%
driver = webdriver.Chrome(r"C:/Users/ACER/Downloads/chromedriver_win32/chromedriver.exe")

# %%
driver.get('https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-11-14&to=2022-11-17&guests=2&page=1')

# %%
name = []
distance = []
rating = []
total_review = []
overall_review = []
privates = []
dorms = []
facilities = []
property_des = []
hostel_url = []


while True:
    hostel_url_tags = driver.find_elements(By.XPATH,'//*[@class="title title-6"]/a')
    for i in hostel_url_tags:
        host_url = i.get_attribute("href")
        hostel_url.append(host_url)
    distances = driver.find_elements(By.XPATH,'//*[@class="description"]')
    for i in distances:
        distance.append(i.text)
    names = driver.find_elements(By.XPATH,'//*[@class="title title-6"]')
    for i in names:
        name.append(i.text)
    try:
        next_ = driver.find_element(By.XPATH, '//*[@class="core-icon icon-core-chevron-right"]')
        next_.click()
        time.sleep(5)
    except:
        break

for i in hostel_url:
    driver.get(i)
    time.sleep(5)
    try:
        property_ = driver.find_element(By.XPATH,'//*[@class="content collapse-content"]')
        property_des.append(property_.text)
    except NoSuchElementException:
        property_des.append('-')
    try:
        facility = driver.find_element(By.XPATH,'//*[@class="facilities"]')
        facilities.append(facility.text)
    except NoSuchElementException:
        facilities.append('-')
    try:
        ratings = driver.find_element(By.XPATH,'//*[@class="score orange big"]')
        rating.append(ratings.text)
    except NoSuchElementException:
        rating.append('-')
    try:
        total_reviews = driver.find_element(By.XPATH,'//*[@class="reviews"]')
        total_review.append(total_reviews.text)
    except NoSuchElementException:
        total_review.append('-')
    try:
        overall_reviews = driver.find_element(By.XPATH,'//*[@class="keyword"]')
        overall_review.append(overall_reviews.text)
    except NoSuchElementException:
        overall_review.append('-')
    try:
        private = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[8]/div/div/section/div/div[1]/div[1]/div[2]/div/div[2]/div[2]/div/div[1]/div[2]/div[1]')
        privates.append(private.text)
    except NoSuchElementException:
        privates.append('-')
    try:
        dorm = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[8]/div/div/section/div/div[1]/div[2]/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[2]/div[1]')
        dorms.append(dorm.text)
    except NoSuchElementException:
        dorms.append('-')

# %%
df = pd.DataFrame({'Name': name, 'Distance from City': distance, 'Rating':rating, 'Total Reviews': total_review, 
                   'Overall Review': overall_review, 'Privates from Price':privates, 'Dorms from Price':dorms, 
                   'Facilities':facilities, 'Property Description':property_des})
df.head(10)
# Out:
#                                       Name               Distance from City  \
# 0              Wombat's City Hostel London  Hostel - 3.6km from city centre
# 1                 St Christopher's Village  Hostel - 1.8km from city centre
# 2                         Generator London    Hostel - 3km from city centre
# 3        Safestay London Elephant & Castle  Hostel - 1.7km from city centre
# 4                  Hostel One Notting Hill  Hostel - 5.5km from city centre
# 5                     Urbany Hostel London  Hostel - 5.4km from city centre
# 6              Smart Russell Square Hostel  Hostel - 2.6km from city centre
# 7  Safestay London Kensington Holland Park  Hostel - 5.9km from city centre
# 8                         Astor Museum Inn  Hostel - 2.2km from city centre
# 9                           Phoenix Hostel  Hostel - 4.2km from city centre
#
#   Rating        Total Reviews Overall Review Privates from Price  \
# 0    9.0  14293 Total Reviews         Superb                   -
# ...
