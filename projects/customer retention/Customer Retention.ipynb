# %%
# importing relevant libraries
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# importing the dataset
df = pd.read_csv('customer_retention_datasheet.csv')
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
# importing the dataset
df1 = pd.read_csv('customer_retention_code.csv')
df1.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
# first 10 elements of the datasheet
df.head(10)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
# 5                Female         31-40 years
# 6                  Male         41-50 yaers
# 7                  Male         41-50 yaers
# 8                Female  Less than 20 years
# 9                Female         31-40 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# 5                                 Noida
# 6                                 Delhi
# 7                                 Delhi
# 8                                 Solan
# 9                                 Delhi
#
# ...

# %%
# first 10 elements of the datasheet
df1.head(10)
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
# 5                      1                    3
# 6                      0                    4
# 7                      0                    4
# 8                      1                    1
# 9                      1                    3
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# 5                                 Noida
# 6                                 Delhi
# 7                                 Delhi
# 8                                 Solan
# 9                                 Delhi
#
# ...

# %%
#Statistical description of the data
df.describe(include=object).transpose()
# Out:
#                                                    count unique  \
# 1Gender of respondent                                269      2
# 2 How old are you?                                   269      5
# 3 Which city do you shop online from?                269     11
# 5 Since How Long You are Shopping Online ?           269      5
# 6 How many times you have made an online purcha...   269      6
# ...                                                  ...    ...
# Longer delivery period                               269      6
# Change in website/Application design                 269      7
# Frequent disruption when moving from one page t...   269      8
# Website is as efficient as before                    269      8
# Which of the Indian online retailer would you r...   269      8
#
#                                                                    top freq
# 1Gender of respondent                                           Female  181
# ...

# %%
# let's define a function we will use for plotting
def bar_chart(ax):
    all_heights = [[p.get_height() for p in bars] for bars in ax.containers]
    for bars in ax.containers:
        for i, p in enumerate(bars):
            total = sum(xgroup[i] for xgroup in all_heights)
            percentage = f'{(100 * p.get_height() / total) :.1f}%'
            ax.annotate(percentage, (p.get_x() + p.get_width() / 2, p.get_height()), size=11, ha='center', va='bottom')

# %%
# let's take a look at the Gender column
fig = plt.figure(figsize =(10, 7))
gender = df['1Gender of respondent'].value_counts().keys()
plt.pie(df['1Gender of respondent'].value_counts(), labels = gender, autopct='%1.1f%%')
print(df['1Gender of respondent'].value_counts())
print('Total:',df['1Gender of respondent'].count())
plt.show()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
# Total: 269

# %% [raw]
# We notice the number of women that shop online are 2x more than the number of men who shop online. From the dataset a striking 67.3% of online customers are women while men only make 32.7% of online customers

# %%
# Lets take a look at the age category of the online customers
age_cat = df['2 How old are you? '].value_counts().keys() 
fig = plt.figure(figsize =(10, 7))
plt.pie(df['2 How old are you? '].value_counts(), labels = age_cat, autopct='%1.1f%%')
print(df['2 How old are you? '].value_counts())
plt.show()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
plt.figure(figsize=(10,5), dpi=80)
sns.countplot(df['2 How old are you? '])
plt.show()

# %% [raw]
# We can see that most of the online cstomers are within the age range of 21 to 50 which coincides with the active population.
# Below 20years and above 50years we have very less customers since most persons within these age are either dependent or have caretakers.

# %%
#let's see the relationship between gender and age
plt.figure(figsize=(10,5), dpi=80)
gender = sns.countplot(x="2 How old are you? ",hue='1Gender of respondent', data=df)
gender.set(xlabel='2 How old are you? ', ylabel='Count')

bar_chart(gender)
plt.show()

# %%
# Lets take a look at the age category of the online customers
cities = df['3 Which city do you shop online from?'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['3 Which city do you shop online from?'].value_counts(), labels = cities, autopct='%1.1f%%')
print(df['3 Which city do you shop online from?'].value_counts())
plt.show()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [raw]
# We can see that most of the online customers are concerntrated in the urban areas or in the bigger cities. This is normal since the urban areas generally have more access to deliveries, better telecomunication and internet services and most importantly, they have bigger populations.

# %%
# Lets take a look at how long people have been Shopping online
duration = df['5 Since How Long You are Shopping Online ?'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['5 Since How Long You are Shopping Online ?'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['5 Since How Long You are Shopping Online ?'].value_counts())
plt.show()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [raw]
# We notice that about 37% of the customers have been shopping for more than 4years online. From here we cannot really conclude if they were happy shopping online, let's try to compare how often they shop to see if they were happy shopping online

# %%
#let's see the relationship between How long customers have been shopping and how often they shop
plt.figure(figsize=(15,5), dpi=80)
durations = sns.countplot(x="5 Since How Long You are Shopping Online ?",hue='6 How many times you have made an online purchase in the past 1 year?', data=df)
durations.set(xlabel='5 Since How Long You are Shopping Online ?', ylabel='Count')

plt.show()

# %% [raw]
# Looks like people are really enjoying shopping online, from the chart above, those with more than online shopping experience tend to shop more often than those with less experience, as the experience grows the shopping frequency also grows.
# However, this could also be due to familiarity, meaning maybe they shop more because they have more knowledge than the less experience. So lets continue exploring to see how satisfied they are.

# %%
# let's see how different online customers acess the internet
duration = df['7 How do you access the internet while shopping on-line?'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['7 How do you access the internet while shopping on-line?'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['7 How do you access the internet while shopping on-line?'].value_counts())
plt.show()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
#let's see the relationship between different internet access methods and how often they shop
plt.figure(figsize=(15,5), dpi=80)
access = sns.countplot(x="7 How do you access the internet while shopping on-line?",hue='6 How many times you have made an online purchase in the past 1 year?', data=df)
access.set(xlabel='7 How do you access the internet while shopping on-line?', ylabel='Count')

plt.show()

# %% [raw]
# We can see that most of the customers use mobile internet for internet access and only a few use wifi, meanwhile a very small 1.5% of customers use dial-up.
# We also see that people using mobile internet do online shopping more often than any other.

# %%
#Let's take a look at the channels people use to get to the online stores
duration = df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts())
plt.show()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %% [raw]
# We can clearly see that most persons are led to the online stores by search engines.
# In tha regard, we can advise online store owners to focus on Search Engine Optimizations(SEO) to get more customers

# %%
#Let's take a look at the channels people use to get to the online stores
duration = df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts())
plt.show()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
#let's see the relationship between shop exploration and how often they shop
plt.figure(figsize=(15,5), dpi=80)
access = sns.countplot(x="14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ",hue='6 How many times you have made an online purchase in the past 1 year?', data=df)
access.set(xlabel='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ', ylabel='Count')

plt.show()

# %% [raw]
# We see that a majority of persons explore the shops for 6mins and above before making purchases.
# We also see that people who explore the shops more tend to buy more
# Shop owners can enhance their sales by using ecommendation engines to present goods that the customers could be interested in

# %%
#Let's take a look at the channels people use to get to the online stores
duration = df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts())
plt.show()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %% [raw]
# We discover that credit/debit cards is the most prefered method of payment for online shopping.
# However, the other payment methods still constitute a great proportion of prefered payment method
# To retain more customers, shop owners should make available all the various payment methods in their shops

# %%
#Let's take a look at the quality on content in the store
duration = df['18 The content on the website must be easy to read and understand'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['18 The content on the website must be easy to read and understand'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['18 The content on the website must be easy to read and understand'].value_counts())
plt.show()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
#let's see the relationship between content quality and how often they shop
plt.figure(figsize=(15,5), dpi=80)
content = sns.countplot(x="18 The content on the website must be easy to read and understand",hue='6 How many times you have made an online purchase in the past 1 year?', data=df)
content.set(xlabel='18 The content on the website must be easy to read and understand', ylabel='Count')

plt.show()

# %% [raw]
# Most people are looking for quality content
# The people who want quality content are those who purchase more frequently
# Shops should make their content easy to read and understand in order to get more customers

# %%
#Let's take a look at the Seller's information and how it influences customers
duration = df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts())
plt.show()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %% [raw]
# As we can clearly see most people prefer that the sellers information be clearly listed on the shops, this creates more trust

# %%
#Let's take a look at how the website navigation could influence the customers
duration = df['22 Ease of navigation in website'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['22 Ease of navigation in website'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['22 Ease of navigation in website'].value_counts())
plt.show()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %% [raw]
# It's clear that over 90% of customers want a website that is easy to navigate

# %%
#Let's take a look at how the website Loading speed could influence the customers
duration = df['23 Loading and processing speed'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['23 Loading and processing speed'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['23 Loading and processing speed'].value_counts())
plt.show()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Indifferent (3)           12
# Strongly disagree (1)     12
# Name: 23 Loading and processing speed, dtype: int64

# %% [raw]
# People need fast websites

# %%
#Let's take a look at how the UI of the website could influence the customers
duration = df['24 User friendly Interface of the website'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['24 User friendly Interface of the website'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['24 User friendly Interface of the website'].value_counts())
plt.show()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %% [markdown]
# UI design of online stores should be at  it's best

# %%
#Let's take a look at how Payment methods could influence the customers
duration = df['25 Convenient Payment methods'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['25 Convenient Payment methods'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['25 Convenient Payment methods'].value_counts())
plt.show()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %% [raw]
# Customers want convenient payment methods

# %%
#Let's take a look at how Return Policies could influence the customers
duration = df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts())
plt.show()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %% [raw]
# Return policies should be listed

# %%
#Let's take a look at how monetary savings could influence the customers
duration = df['41 Monetary savings'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['41 Monetary savings'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['41 Monetary savings'].value_counts())
plt.show()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %% [markdown]
# Generally people always try to save so they can shop more for less

# %%
#Let's take a look at how Adventure could influence the customers
duration = df['43 Shopping on the website gives you the sense of adventure'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['43 Shopping on the website gives you the sense of adventure'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['43 Shopping on the website gives you the sense of adventure'].value_counts())
plt.show()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %% [raw]
# People love the adventure in a shop, however, a great proportion of persons (about 40%) are not really interested in the adventure

# %%
#Let's take a look at how Adventure could influence the customers
duration = df['45 You feel gratification shopping on your favorite e-tailer'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['45 You feel gratification shopping on your favorite e-tailer'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['45 You feel gratification shopping on your favorite e-tailer'].value_counts())
plt.show()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %% [raw]
# People are not really concerned about gratification

# %%
#Let's take a look at how Value for Money could influence the customers
duration = df['47 Getting value for money spent'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['47 Getting value for money spent'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['47 Getting value for money spent'].value_counts())
plt.show()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %%
#let's see the relationship between value for money and how often they shop
plt.figure(figsize=(15,5), dpi=80)
content = sns.countplot(x="47 Getting value for money spent",hue='6 How many times you have made an online purchase in the past 1 year?', data=df)
content.set(xlabel='47 Getting value for money spent', ylabel='Count')

plt.show()

# %% [raw]
# People don't joke with money, they always want value for each dime spent

# %%
#Let's take a look at how Monetary Benefits could influence the customers
duration = df['30 Online shopping gives monetary benefit and discounts'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['30 Online shopping gives monetary benefit and discounts'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['30 Online shopping gives monetary benefit and discounts'].value_counts())
plt.show()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
#let's see the relationship between monetary benefits and how often they shop
plt.figure(figsize=(15,5), dpi=80)
content = sns.countplot(x="30 Online shopping gives monetary benefit and discounts",hue='6 How many times you have made an online purchase in the past 1 year?', data=df)
content.set(xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='Count')

plt.show()

# %%
#Let's take a look at how Monetary Benefits could influence the customers
duration = df['Easy to use website or application'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['Easy to use website or application'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['Easy to use website or application'].value_counts())
plt.show()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
#Let's take a look at how Monetary Benefits could influence the customers
duration = df['Which of the Indian online retailer would you recommend to a friend?'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['Which of the Indian online retailer would you recommend to a friend?'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['Which of the Indian online retailer would you recommend to a friend?'].value_counts())
plt.show()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
#Let's take a look at how Monetary Benefits could influence the customers
duration = df['Quickness to complete purchase'].value_counts().keys()
fig = plt.figure(figsize =(10, 7))
plt.pie(df['Quickness to complete purchase'].value_counts(), labels = duration, autopct='%1.1f%%')
print(df['Quickness to complete purchase'].value_counts())
plt.show()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Flipkart.com                                                 15
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df1['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ']
# Out:
# 0                                   Amazon.in, Paytm.com
# 1      Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                       Amazon.in, Paytm.com, Myntra.com
# 3      Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4      Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#                              ...
# 264                                            Amazon.in
# 265                              Amazon.in, Flipkart.com
# 266                Amazon.in, Flipkart.com, Snapdeal.com
# 267    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                            Amazon.in
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , Length: 269, dtype: object
